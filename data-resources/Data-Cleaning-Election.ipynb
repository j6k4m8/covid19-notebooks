# %%
import pandas as pd

# %%
df = pd.read_csv("1976-2020-president.csv")
df = df[(df.year >= 2020) & (df.writein == False) & (df.party_simplified.isin(['DEMOCRAT', "REPUBLICAN"]))]

# %%
df = df[['state', 'candidatevotes', 'totalvotes']]
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 3740  2020        ALABAMA       AL           1         63        41
# 3741  2020        ALABAMA       AL           1         63        41
# 3744  2020         ALASKA       AK           2         94        81
# 3745  2020         ALASKA       AK           2         94        81
# 3752  2020        ARIZONA       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 4264  2020  WEST VIRGINIA       WV          54         55        56
# 4267  2020      WISCONSIN       WI          55         35        25
# 4268  2020      WISCONSIN       WI          55         35        25
# 4280  2020        WYOMING       WY          56         83        68
# 4281  2020        WYOMING       WY          56         83        68
#
#             office            candidate party_detailed writein  \
# 3740  US PRESIDENT  BIDEN, JOSEPH R. JR       DEMOCRAT   False
# ...
